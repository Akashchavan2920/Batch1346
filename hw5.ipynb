# %%
a=23.236
print(a)
# Out:
# 23.236

# %%
b=56442.236

# %%
print(a-b)
print(type(a))
print(type(b))
print(id(a))
print(id(b))
# Out:
# -56419.0
# <class 'float'>
# <class 'float'>
# 2040806546256
# 2040787993072
