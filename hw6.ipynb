# %%
a=86.47
print(a)
# Out:
# 86.47

# %%
b="akki"
print(b)
# Out:
# akki

# %%
c=56
print(c)
print(type(a))
print(type(b))
print(type(c))
print(id(a))
print(id(b))
print(id(c))
# Out:
# 56
# <class 'float'>
# <class 'str'>
# <class 'int'>
# 1734372609616
# 1734374005312
# 140731835804504
