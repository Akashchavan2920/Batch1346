# %%
a="akki"
print(a)
# Out:
# akki

# %%
b=" she from shirampur"

# %%
print(a)
print(b)
print(type(a))
print(type(b))
print(id(a))
print(id(b))
# Out:
# akki
#  she from shirampur
# <class 'str'>
# <class 'str'>
# 2522121415888
# 2522125267504
