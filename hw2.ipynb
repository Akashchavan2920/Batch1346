# %%
a=12
b=10
y=(a+b)
print(y)
# Out:
# 22

# %%
s=y*b+a

# %%
print(s)
print(type(s))
print(type(y))
print(id(a))
print(id(y))
print(id(b))
print(id(s))
# Out:
# 232
# <class 'int'>
# <class 'int'>
# 140731835803096
# 140731835803416
# 140731835803032
# 140731835810136
